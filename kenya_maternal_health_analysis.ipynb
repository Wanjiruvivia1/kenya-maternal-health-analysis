# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanjiruvivia1/kenya-maternal-health-analysis/blob/main/kenya_maternal_health_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kenya Maternal & Child Health Analysis

# %% [markdown]
# ## 1. Introduction & Objectives

# %% [markdown]
# ## 2. Import Libraries

# %% [markdown]
# ## 3. Load & Explore Data

# %% [markdown]
# ## 4. Data Cleaning

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 5.1 Maternal Health Indicators

# %% [markdown]
# ### 5.2 Child Health Indicators

# %% [markdown]
# ### 5.3 County-Level Disparities

# %% [markdown]
# ## 6. Statistical Analysis

# %% [markdown]
# ## 7. Key Findings & Insights

# %% [markdown]
# ## 8. Conclusions & Recommendations

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8')

print("Libraries loaded successfully ✅")
# Out:
# Libraries loaded successfully ✅
